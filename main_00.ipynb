# %% [markdown]
# # 1. Install library(& freeze)

# %%
#!pip3 freeze > requirements.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: contourpy==1.0.7 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: Cython==0.29.33 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.29.33)
# Requirement already satisfied: et-xmlfile==1.1.0 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: fonttools==4.39.0 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (4.39.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: joblib==1.2.0 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: kiwisolver==1.4.4 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: matplotlib==3.7.1 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (3.7.1)
# Requirement already satisfied: numpy==1.24.2 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (1.24.2)
# Requirement already satisfied: openpyxl==3.1.2 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: pandas==1.5.3 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (1.5.3)
# Requirement already satisfied: patsy==0.5.3 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: Pillow==9.4.0 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (9.4.0)
# Requirement already satisfied: pmdarima==2.0.3 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (2.0.3)
# Requirement already satisfied: pyparsing==3.0.9 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: pytz==2022.7.1 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (2022.7.1)
# Requirement already satisfied: scikit-learn==1.2.2 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (1.10.1)
# Requirement already satisfied: statsmodels==0.13.5 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (0.13.5)
# Requirement already satisfied: threadpoolctl==3.1.0 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (3.1.0)
# Requirement already satisfied: urllib3==1.26.15 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (1.26.15)
# Requirement already satisfied: webencodings==0.5.1 in ./.conda/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (0.5.1)
# Requirement already satisfied: packaging>=20.0 in ./.conda/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 9)) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: six in ./.conda/lib/python3.11/site-packages (from patsy==0.5.3->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in ./.conda/lib/python3.11/site-packages (from pmdarima==2.0.3->-r requirements.txt (line 15)) (67.6.0)

# %% [markdown]
# ### Load library

# %%
#load library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#load forecastingn tools
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima import auto_arima

#load eval tools
from sklearn.metrics import mean_squared_log_error, mean_absolute_percentage_error #MAPE, WMAPE
from statsmodels.tools.eval_measures import rmse

#ignore harmless warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ### load original dataframe

# %%
original_df = pd.read_excel('data.xlsx', index_col='submitted_date', parse_dates=True)

pd.set_option("display.max_rows", original_df.shape[0])
original_df['file_size_per_rec'] = original_df['file_size_gb']/original_df['records']*1000 #into MB
original_df.index = pd.to_datetime(original_df.index)

original_df.head()
# Out:
#                    records  file_size_gb  file_size_per_rec
# submitted_date
# 2012-03-01             0.0      0.000874                inf
# 2012-04-01      68570206.0  57843.503303           0.843566
# 2012-05-01      70764937.0  53755.010719           0.759628
# 2012-06-01      70276934.0  51089.201694           0.726970
# 2012-07-01      72163073.0  57436.068959           0.795920

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 131 entries, 2012-03-01 to 2023-01-01
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   records            130 non-null    float64
#  1   file_size_gb       130 non-null    float64
#  2   file_size_per_rec  130 non-null    float64
# dtypes: float64(3)
# memory usage: 4.1 KB

# %%
original_df.isnull().sum().sort_values(ascending = False)
# Out:
# records              1
# file_size_gb         1
# file_size_per_rec    1
# dtype: int64

# %%
original_df.describe()
# Out:
#             records   file_size_gb  file_size_per_rec
# count  1.300000e+02     130.000000         130.000000
# mean   1.191958e+08  118546.352699                inf
# std    5.785218e+07   51286.528102                NaN
# min    0.000000e+00       0.000874           0.360643
# 25%    7.665259e+07   67904.114447           0.886991
# 50%    1.139575e+08  117289.622867           0.981050
# 75%    1.410827e+08  164550.493823           1.115651
# max    5.498661e+08  210865.107593                inf

# %% [markdown]
# ##### Graph - Whole 10 years

# %%
def viz(df):
    plt.figure(figsize=(30,20))
    cols = df.columns
    l = len(cols)
    for i,c in enumerate(cols):
        print(i,c)
        plt.subplot(l,1,i+1)
        #plt.plot(df.submitted_date, df[c])
        plt.plot(df[c])
        plt.title(c)

    plt.show()

viz(original_df)
# Out:
# 0 records
# 1 file_size_gb
# 2 file_size_per_rec

# %% [markdown]
# ##### Graph - After Jun 2020

# %%
tempdf = original_df['2020-06':]
viz(tempdf)
# Out:
# 0 records
# 1 file_size_gb
# 2 file_size_per_rec

# %%
tempdf
# Out:
#                     records   file_size_gb  file_size_per_rec
# submitted_date
# 2020-06-01      135640104.0  169716.569124           1.251227
# 2020-07-01      220099737.0  179618.550297           0.816078
# 2020-08-01      174190352.0  170909.299443           0.981164
# 2020-09-01      146153884.0  169901.356074           1.162483
# 2020-10-01      165114662.0  181930.844124           1.101845
# 2020-11-01      157395317.0  166978.232563           1.060884
# 2020-12-01      157743014.0  171218.638941           1.085428
# 2021-01-01      146343183.0  164712.781319           1.125524
# 2021-02-01      143228431.0  161215.277410           1.125582
# 2021-03-01      161608966.0  186426.537030           1.153566
# 2021-04-01      549866053.0  198305.233768           0.360643
# 2021-05-01      160825262.0  161269.382750           1.002762
# 2021-06-01      154406750.0  172619.325154           1.117952
# 2021-07-01      162510495.0  179806.431554           1.106430
# 2021-08-01      151668040.0  172244.305162           1.135666
# 2021-09-01      168660158.0  185893.428650           1.102177
# 2021-10-01      197499152.0  190912.447724           0.966649
# 2021-11-01      196757570.0  189518.573737           0.963209
# 2021-12-01      177274215.0  184692.054883           1.041844
# 2022-01-01      175016012.0  179978.746271           1.028356
# 2022-02-01      174026236.0  172266.099968           0.989886
# 2022-03-01      195778951.0  198599.452134           1.014407
# 2022-04-01      178013421.0  189866.486698           1.066585
# 2022-05-01      182786670.0  204087.179591           1.116532
# 2022-06-01      252329115.0  192333.388544           0.762232
# 2022-07-01      208129244.0  207857.828844           0.998696
# 2022-08-01      180081963.0  201925.201299           1.121296
# 2022-09-01      176125051.0  200120.592662           1.136242
# 2022-10-01      207894540.0  208974.574449           1.005195
# 2022-11-01      215259474.0  210865.107593           0.979586
# 2022-12-01      215117324.0  208009.046105           0.966956
# 2023-01-01              NaN            NaN                NaN

# %%
temp_size = tempdf[['file_size_gb']]
#temp_size
print((temp_size.loc['2021-04-01'] - temp_size.loc['2021-03-01'])/temp_size.loc['2021-03-01']*100)
# Out:
# file_size_gb    6.371784
# dtype: float64

# %%
print((temp_size.loc['2021-04-01'] - temp_size.loc['2021-03-01']))
# Out:
# file_size_gb    11878.696738
# dtype: float64

# %%
temp_rec = tempdf[['records']]
#temp_rec
print((temp_rec.loc['2021-04-01'] - temp_rec.loc['2021-03-01'])/temp_rec.loc['2021-03-01']*100)
# Out:
# records    240.244769
# dtype: float64

# %%
temp_size_per_rec = tempdf[['file_size_per_rec']]
print((temp_size_per_rec.loc['2021-04-01'] - temp_size_per_rec.loc['2021-03-01'])/temp_size_per_rec.loc['2021-03-01']*100)
# Out:
# file_size_per_rec   -68.736688
# dtype: float64

# %%
#What 10 months have the highest file size loaded?
original_df.sort_values(by='file_size_gb', ascending=False).head(10)
# Out:
#                     records   file_size_gb  file_size_per_rec
# submitted_date
# 2022-11-01      215259474.0  210865.107593           0.979586
# 2022-10-01      207894540.0  208974.574449           1.005195
# 2022-12-01      215117324.0  208009.046105           0.966956
# 2022-07-01      208129244.0  207857.828844           0.998696
# 2022-05-01      182786670.0  204087.179591           1.116532
# 2022-08-01      180081963.0  201925.201299           1.121296
# 2022-09-01      176125051.0  200120.592662           1.136242
# 2022-03-01      195778951.0  198599.452134           1.014407
# 2021-04-01      549866053.0  198305.233768           0.360643
# 2022-06-01      252329115.0  192333.388544           0.762232

# %%
#Bar plot describing the avg. value in filesize per year
original_df.resample('Y').mean().plot.bar(figsize=(6,4))
# Out:
# <Axes: xlabel='submitted_date'>

# %%
yearly = original_df.resample('Y').mean()
yearly_shift = yearly.shift(1)
chg = yearly - yearly_shift
chg['file_size_gb'].idxmax()
# Out:
# Timestamp('2017-12-31 00:00:00', freq='A-DEC')

# %% [markdown]
# ##### Questions for EDA
# 1. Quarterly/monthly features(patterns) for 10-years
# 2. The change of average upload file size per record
# 3. What kind of small datasets

# %% [markdown]
# ##### Rolling quartly, yearly for MA(Moving Average)

# %% [markdown]
# MA -> EWMA necessary

# %%
df = pd.read_excel('data.xlsx', index_col='submitted_date', parse_dates=True)

pd.set_option("display.max_rows", df.shape[0])
df['file_size_per_rec'] = df['file_size_gb']/df['records']*1000 #into MB
df.index = pd.to_datetime(df.index)

df.head()
# Out:
#                    records  file_size_gb  file_size_per_rec
# submitted_date
# 2012-03-01             0.0      0.000874                inf
# 2012-04-01      68570206.0  57843.503303           0.843566
# 2012-05-01      70764937.0  53755.010719           0.759628
# 2012-06-01      70276934.0  51089.201694           0.726970
# 2012-07-01      72163073.0  57436.068959           0.795920

# %%
df['mean_yearly'] = df['file_size_gb'].rolling(window=12).mean()
df.head()
# Out:
#                    records  file_size_gb  file_size_per_rec  mean_yearly
# submitted_date
# 2012-03-01             0.0      0.000874                inf          NaN
# 2012-04-01      68570206.0  57843.503303           0.843566          NaN
# 2012-05-01      70764937.0  53755.010719           0.759628          NaN
# 2012-06-01      70276934.0  51089.201694           0.726970          NaN
# 2012-07-01      72163073.0  57436.068959           0.795920          NaN

# %%
#df[['file_size_gb', 'mean_yearly']].plot(figsize=(10,6))

# %% [markdown]
# ##### monthly boxplot

# %%
df = pd.read_excel('data.xlsx', index_col='submitted_date', parse_dates=True)
df.index = pd.to_datetime(df.index)
df = df[['file_size_gb']]
df['Month'] = df.index.month
#df['Month'] = df.index.strftime('%B')

df.head()
# Out:
#                 file_size_gb  Month
# submitted_date
# 2012-03-01          0.000874      3
# 2012-04-01      57843.503303      4
# 2012-05-01      53755.010719      5
# 2012-06-01      51089.201694      6
# 2012-07-01      57436.068959      7

# %%
#Boxplot groups by the Month 
df.boxplot(by='Month', figsize=(20,10))
# Out:
# <Axes: title={'center': 'file_size_gb'}, xlabel='[Month]'>

# %% [markdown]
# ### Insights from EDA
# 1. What was the percent increase in records, and file size from Mar 2021 to Apr 2021?
#
# April 2021 records up +240.24% from last month, On the other hand, the uploaded file size increased by +6.37%(11,878.69GB), which is very small compared to the # of the increased records
#
# 2. How did the size per file (MB) change compared to last month in April 2021, when the number of uploads soared, ?
#
# Average file size per record decreased by -68.73% in April(0.36MB) compared to March(1.15MB) 2021. It seems necessary to manually check which small files have been uploaded in bulk by user or file type.
#
# 3. Which year the biggest increase in mean from the previous year's mean?
#
# Btwn 2016 and 2017
#
# 4. Change in the amount of upload file size per month?
#
# Upload file size increased in the second half of the year than in the first half

# %% [markdown]
# # 3. TSA(Time Series Analysis)

# %% [markdown]
# ##### *) Load data newly

# %%
df = pd.read_excel('data.xlsx', index_col='submitted_date', parse_dates=True)
df.index = pd.to_datetime(df.index)
df.index.names = ['Date']
print(df.head(), df.tail())
# Out:
#                records  file_size_gb
# Date
# 2012-03-01         0.0      0.000874
# 2012-04-01  68570206.0  57843.503303
# 2012-05-01  70764937.0  53755.010719
# 2012-06-01  70276934.0  51089.201694
# 2012-07-01  72163073.0  57436.068959                 records   file_size_gb
# Date
# 2022-09-01  176125051.0  200120.592662
# 2022-10-01  207894540.0  208974.574449
# 2022-11-01  215259474.0  210865.107593
# 2022-12-01  215117324.0  208009.046105
# 2023-01-01          NaN            NaN

# %%
#remove missing values - the first one & the last one to be predicted
df = df.iloc[1:-1]

# %% [markdown]
# # 3-1) Smoothing

# %% [markdown]
# ##### SMA(Simple Moving Avg.) 12-month

# %%
df['file_size_gb'].plot(figsize=(8,5))
df.rolling(window=12).mean()['file_size_gb'].plot() #Yearly(12M) mean
# Out:
# <Axes: xlabel='Date'>

# %%
#12months
df['EWMA-12'] = df['file_size_gb'].ewm(span=12).mean()
df[['file_size_gb', 'EWMA-12']].plot(figsize=(8,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ##### SimpleExpSmoothing
# - EWMA(Exponentially Weighted) w/ a span 12, statsmodels.SimpleExpSmoothing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 129 entries, 2012-04-01 to 2022-12-01
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   records       129 non-null    float64
#  1   file_size_gb  129 non-null    float64
#  2   EWMA-12       129 non-null    float64
# dtypes: float64(3)
# memory usage: 4.0 KB

# %% [markdown]
# ##### *) Assign a frequency of 'MS' to the DatetimeIndex

# %%
#set datatime freq. MS(Each data starts the 1st day in every month)
df.index.freq = 'MS'
df.index
# Out:
# DatetimeIndex(['2012-04-01', '2012-05-01', '2012-06-01', '2012-07-01',
#                '2012-08-01', '2012-09-01', '2012-10-01', '2012-11-01',
#                '2012-12-01', '2013-01-01',
#                ...
#                '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01',
#                '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
#                '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', name='Date', length=129, freq='MS')

# %%
print(df.head(), df.tail())
# Out:
#                records  file_size_gb       EWMA-12
# Date
# 2012-04-01  68570206.0  57843.503303  57843.503303
# 2012-05-01  70764937.0  53755.010719  55628.903153
# 2012-06-01  70276934.0  51089.201694  53857.056625
# 2012-07-01  72163073.0  57436.068959  54986.810950
# 2012-08-01  71651811.0  59746.605215  56280.030040                 records   file_size_gb        EWMA-12
# Date
# 2022-08-01  180081963.0  201925.201299  192242.772831
# 2022-09-01  176125051.0  200120.592662  193454.745114
# 2022-10-01  207894540.0  208974.574449  195842.411167
# 2022-11-01  215259474.0  210865.107593  198153.595234
# 2022-12-01  215117324.0  208009.046105  199669.818445

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
span=12
alpha = 2/(span+1)
df['EWMA12'] = df['file_size_gb'].ewm(alpha=alpha, adjust=False).mean()
df.head(10)
# Out:
#                records  file_size_gb       EWMA-12        EWMA12
# Date
# 2012-04-01  68570206.0  57843.503303  57843.503303  57843.503303
# 2012-05-01  70764937.0  53755.010719  55628.903153  57214.504444
# 2012-06-01  70276934.0  51089.201694  53857.056625  56272.150175
# 2012-07-01  72163073.0  57436.068959  54986.810950  56451.214603
# 2012-08-01  71651811.0  59746.605215  56280.030040  56958.197774
# 2012-09-01  75368726.0  54513.445203  55850.656985  56582.081994
# 2012-10-01  77782176.0  61984.471254  57219.396179  57413.218803
# 2012-11-01  75404830.0  59072.326168  57606.074108  57668.466090
# 2012-12-01  70265920.0  52947.732420  56684.488318  56942.199372
# 2013-01-01  72786794.0  59692.162096  57254.441330  57365.270560

# %%
model = SimpleExpSmoothing(df['file_size_gb']).fit(smoothing_level=alpha, optimized=False)
model

# %%
model.fittedvalues
# Out:
# Date
# 2012-04-01     57843.503303
# 2012-05-01     57843.503303
# 2012-06-01     57214.504444
# 2012-07-01     56272.150175
# 2012-08-01     56451.214603
# 2012-09-01     56958.197774
# 2012-10-01     56582.081994
# 2012-11-01     57413.218803
# 2012-12-01     57668.466090
# 2013-01-01     56942.199372
# 2013-02-01     57365.270560
# 2013-03-01     57284.584729
# 2013-04-01     57654.315390
# 2013-05-01     58415.539792
# 2013-06-01     58457.109689
# 2013-07-01     58051.627643
# 2013-08-01     58996.531699
# 2013-09-01     58860.910407
# 2013-10-01     58818.492539
# 2013-11-01     59860.412062
# 2013-12-01     60264.352161
# 2014-01-01     60346.042301
# 2014-02-01     60722.141587
# 2014-03-01     60304.529956
# 2014-04-01     61109.327295
# 2014-05-01     61397.170166
# 2014-06-01     61345.059493
# 2014-07-01     61459.316390
# 2014-08-01     62176.954438
# 2014-09-01     62523.351544
# 2014-10-01     63407.467402
# 2014-11-01     64591.783076
# 2014-12-01     64631.207839
# 2015-01-01     65164.570411
# 2015-02-01     65673.606486
# 2015-03-01     65266.865758
# 2015-04-01     66387.385627
# 2015-05-01     66973.148478
# 2015-06-01     67106.427852
# 2015-07-01     68134.302987
# 2015-08-01     69207.065923
# 2015-09-01     70184.310005
# 2015-10-01     71238.582275
# 2015-11-01     72645.859106
# 2015-12-01     74119.270886
# 2016-01-01     74909.525540
# 2016-02-01     75338.390725
# 2016-03-01     75786.353415
# 2016-04-01     76563.909202
# 2016-05-01     77707.018184
# 2016-06-01     78737.054208
# 2016-07-01     79776.465966
# 2016-08-01     80905.757495
# 2016-09-01     82497.762101
# 2016-10-01     84315.071642
# 2016-11-01     86192.330692
# 2016-12-01     87818.007325
# 2017-01-01     88870.130943
# 2017-02-01     90996.150705
# 2017-03-01     92635.630982
# 2017-04-01     95471.493958
# 2017-05-01     96482.886563
# 2017-06-01     99293.170200
# 2017-07-01    101578.897193
# 2017-08-01    103763.435477
# 2017-09-01    106633.030936
# 2017-10-01    108706.322854
# 2017-11-01    111921.629530
# 2017-12-01    114442.419230
# 2018-01-01    115112.946994
# 2018-02-01    118000.652885
# 2018-03-01    118172.414195
# 2018-04-01    119793.148499
# 2018-05-01    122396.119414
# 2018-06-01    124866.037671
# 2018-07-01    126747.679328
# 2018-08-01    130406.756712
# 2018-09-01    132828.917836
# 2018-10-01    133545.466472
# 2018-11-01    137375.015216
# 2018-12-01    139090.156294
# 2019-01-01    139399.690838
# 2019-02-01    142392.408160
# 2019-03-01    141595.745748
# 2019-04-01    143654.324490
# 2019-05-01    146056.457254
# 2019-06-01    147499.641264
# 2019-07-01    147712.296977
# 2019-08-01    149780.991490
# 2019-09-01    150532.702632
# 2019-10-01    152614.383971
# 2019-11-01    154972.292176
# 2019-12-01    154919.419693
# 2020-01-01    154725.722858
# 2020-02-01    156301.605939
# 2020-03-01    155367.623408
# 2020-04-01    157626.472742
# 2020-05-01    159470.195757
# 2020-06-01    158246.397205
# 2020-07-01    160011.039039
# 2020-08-01    163027.579233
# 2020-09-01    164240.151573
# 2020-10-01    165111.106111
# 2020-11-01    167698.758113
# 2020-12-01    167587.908029
# 2021-01-01    168146.482015
# 2021-02-01    167618.220370
# 2021-03-01    166633.152222
# 2021-04-01    169678.288346
# 2021-05-01    174082.433796
# 2021-06-01    172111.195173
# 2021-07-01    172189.369017
# 2021-08-01    173361.224792
# 2021-09-01    173189.391002
# 2021-10-01    175143.858333
# 2021-11-01    177569.795162
# 2021-12-01    179408.068789
# 2022-01-01    180220.989727
# 2022-02-01    180183.721503
# 2022-03-01    178965.625882
# 2022-04-01    181986.214536
# 2022-05-01    183198.564099
# 2022-06-01    186412.197252
# 2022-07-01    187323.149758
# 2022-08-01    190482.331156
# 2022-09-01    192242.772717
# 2022-10-01    193454.745016
# 2022-11-01    195842.411083
# 2022-12-01    198153.595161
# Freq: MS, dtype: float64

# %%
model.fittedvalues.shift(-1) #한칸씩 밀어주기
# Out:
# Date
# 2012-04-01     57843.503303
# 2012-05-01     57214.504444
# 2012-06-01     56272.150175
# 2012-07-01     56451.214603
# 2012-08-01     56958.197774
# 2012-09-01     56582.081994
# 2012-10-01     57413.218803
# 2012-11-01     57668.466090
# 2012-12-01     56942.199372
# 2013-01-01     57365.270560
# 2013-02-01     57284.584729
# 2013-03-01     57654.315390
# 2013-04-01     58415.539792
# 2013-05-01     58457.109689
# 2013-06-01     58051.627643
# 2013-07-01     58996.531699
# 2013-08-01     58860.910407
# 2013-09-01     58818.492539
# 2013-10-01     59860.412062
# 2013-11-01     60264.352161
# 2013-12-01     60346.042301
# 2014-01-01     60722.141587
# 2014-02-01     60304.529956
# 2014-03-01     61109.327295
# 2014-04-01     61397.170166
# 2014-05-01     61345.059493
# 2014-06-01     61459.316390
# 2014-07-01     62176.954438
# 2014-08-01     62523.351544
# 2014-09-01     63407.467402
# 2014-10-01     64591.783076
# 2014-11-01     64631.207839
# 2014-12-01     65164.570411
# 2015-01-01     65673.606486
# 2015-02-01     65266.865758
# 2015-03-01     66387.385627
# 2015-04-01     66973.148478
# 2015-05-01     67106.427852
# 2015-06-01     68134.302987
# 2015-07-01     69207.065923
# 2015-08-01     70184.310005
# 2015-09-01     71238.582275
# 2015-10-01     72645.859106
# 2015-11-01     74119.270886
# 2015-12-01     74909.525540
# 2016-01-01     75338.390725
# 2016-02-01     75786.353415
# 2016-03-01     76563.909202
# 2016-04-01     77707.018184
# 2016-05-01     78737.054208
# 2016-06-01     79776.465966
# 2016-07-01     80905.757495
# 2016-08-01     82497.762101
# 2016-09-01     84315.071642
# 2016-10-01     86192.330692
# 2016-11-01     87818.007325
# 2016-12-01     88870.130943
# 2017-01-01     90996.150705
# 2017-02-01     92635.630982
# 2017-03-01     95471.493958
# 2017-04-01     96482.886563
# 2017-05-01     99293.170200
# 2017-06-01    101578.897193
# 2017-07-01    103763.435477
# 2017-08-01    106633.030936
# 2017-09-01    108706.322854
# 2017-10-01    111921.629530
# 2017-11-01    114442.419230
# 2017-12-01    115112.946994
# 2018-01-01    118000.652885
# 2018-02-01    118172.414195
# 2018-03-01    119793.148499
# 2018-04-01    122396.119414
# 2018-05-01    124866.037671
# 2018-06-01    126747.679328
# 2018-07-01    130406.756712
# 2018-08-01    132828.917836
# 2018-09-01    133545.466472
# 2018-10-01    137375.015216
# 2018-11-01    139090.156294
# 2018-12-01    139399.690838
# 2019-01-01    142392.408160
# 2019-02-01    141595.745748
# 2019-03-01    143654.324490
# 2019-04-01    146056.457254
# 2019-05-01    147499.641264
# 2019-06-01    147712.296977
# 2019-07-01    149780.991490
# 2019-08-01    150532.702632
# 2019-09-01    152614.383971
# 2019-10-01    154972.292176
# 2019-11-01    154919.419693
# 2019-12-01    154725.722858
# 2020-01-01    156301.605939
# 2020-02-01    155367.623408
# 2020-03-01    157626.472742
# 2020-04-01    159470.195757
# 2020-05-01    158246.397205
# 2020-06-01    160011.039039
# 2020-07-01    163027.579233
# 2020-08-01    164240.151573
# 2020-09-01    165111.106111
# 2020-10-01    167698.758113
# 2020-11-01    167587.908029
# 2020-12-01    168146.482015
# 2021-01-01    167618.220370
# 2021-02-01    166633.152222
# 2021-03-01    169678.288346
# 2021-04-01    174082.433796
# 2021-05-01    172111.195173
# 2021-06-01    172189.369017
# 2021-07-01    173361.224792
# 2021-08-01    173189.391002
# 2021-09-01    175143.858333
# 2021-10-01    177569.795162
# 2021-11-01    179408.068789
# 2021-12-01    180220.989727
# 2022-01-01    180183.721503
# 2022-02-01    178965.625882
# 2022-03-01    181986.214536
# 2022-04-01    183198.564099
# 2022-05-01    186412.197252
# 2022-06-01    187323.149758
# 2022-07-01    190482.331156
# 2022-08-01    192242.772717
# 2022-09-01    193454.745016
# 2022-10-01    195842.411083
# 2022-11-01    198153.595161
# 2022-12-01              NaN
# Freq: MS, dtype: float64

# %%
#SimpleExpSmoothing
df['SES12'] = model.fittedvalues.shift(-1)
df.head(10)

#단일지수평활법이 EWMA와 완전히 동일. EWMA12 == SES12
# Out:
#                records  file_size_gb       EWMA-12        EWMA12         SES12
# Date
# 2012-04-01  68570206.0  57843.503303  57843.503303  57843.503303  57843.503303
# 2012-05-01  70764937.0  53755.010719  55628.903153  57214.504444  57214.504444
# 2012-06-01  70276934.0  51089.201694  53857.056625  56272.150175  56272.150175
# 2012-07-01  72163073.0  57436.068959  54986.810950  56451.214603  56451.214603
# 2012-08-01  71651811.0  59746.605215  56280.030040  56958.197774  56958.197774
# 2012-09-01  75368726.0  54513.445203  55850.656985  56582.081994  56582.081994
# 2012-10-01  77782176.0  61984.471254  57219.396179  57413.218803  57413.218803
# 2012-11-01  75404830.0  59072.326168  57606.074108  57668.466090  57668.466090
# 2012-12-01  70265920.0  52947.732420  56684.488318  56942.199372  56942.199372
# 2013-01-01  72786794.0  59692.162096  57254.441330  57365.270560  57365.270560

# %% [markdown]
# ##### DoubleExponentialSmoothing w/ Winter-Holters

# %%
df[['file_size_gb', 'EWMA12', 'SES12']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
df['DES12'] = ExponentialSmoothing(df['file_size_gb'], trend='add').fit().fittedvalues.shift(-1)
df.head()
# Out:
#                records  file_size_gb       EWMA-12        EWMA12  \
# Date
# 2012-04-01  68570206.0  57843.503303  57843.503303  57843.503303
# 2012-05-01  70764937.0  53755.010719  55628.903153  57214.504444
# 2012-06-01  70276934.0  51089.201694  53857.056625  56272.150175
# 2012-07-01  72163073.0  57436.068959  54986.810950  56451.214603
# 2012-08-01  71651811.0  59746.605215  56280.030040  56958.197774
#
#                    SES12         DES12
# Date
# 2012-04-01  57843.503303  56077.569292
# 2012-05-01  57214.504444  56051.770372
# 2012-06-01  56272.150175  55433.751500
# 2012-07-01  56451.214603  56057.630245
# 2012-08-01  56958.197774  57074.852144

# %%
df[['file_size_gb','SES12', 'DES12']].plot(figsize=(8,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df[['file_size_gb','SES12', 'DES12']].iloc[-12:].plot(figsize=(8,5)) #the recent year(2022)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ##### TripleExponentialSmoothing w/ Winter-Holters

# %%
df['TES12'] = ExponentialSmoothing(df['file_size_gb'], trend='add',seasonal='add', seasonal_periods=12 ).fit().fittedvalues.shift(-1)
df.head()
# Out:
#                records  file_size_gb       EWMA-12        EWMA12  \
# Date
# 2012-04-01  68570206.0  57843.503303  57843.503303  57843.503303
# 2012-05-01  70764937.0  53755.010719  55628.903153  57214.504444
# 2012-06-01  70276934.0  51089.201694  53857.056625  56272.150175
# 2012-07-01  72163073.0  57436.068959  54986.810950  56451.214603
# 2012-08-01  71651811.0  59746.605215  56280.030040  56958.197774
#
#                    SES12         DES12         TES12
# Date
# 2012-04-01  57843.503303  56077.569292  55519.593240
# 2012-05-01  57214.504444  56051.770372  55934.908239
# 2012-06-01  56272.150175  55433.751500  58111.522234
# 2012-07-01  56451.214603  56057.630245  56357.420964
# 2012-08-01  56958.197774  57074.852144  58374.706978

# %%
df[['file_size_gb','SES12', 'DES12', 'TES12']].plot(figsize=(8,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df[['file_size_gb','SES12', 'DES12', 'TES12']].iloc[-12:].plot(figsize=(8,5)) #the recent year(2022)
# Out:
# <Axes: xlabel='Date'>

# %%
df.columns
# Out:
# Index(['records', 'file_size_gb', 'EWMA-12', 'EWMA12', 'SES12', 'DES12',
#        'TES12'],
#       dtype='object')

# %%
df = df[['file_size_gb', 'DES12']]
df.head()
# Out:
#             file_size_gb         DES12
# Date
# 2012-04-01  57843.503303  56077.569292
# 2012-05-01  53755.010719  56051.770372
# 2012-06-01  51089.201694  55433.751500
# 2012-07-01  57436.068959  56057.630245
# 2012-08-01  59746.605215  57074.852144

# %%
df.plot(figsize=(8,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ##### *) Multiplicative w/ DES

# %%
df['DES12_mul'] = ExponentialSmoothing(df['file_size_gb'], trend='mul',seasonal='mul', seasonal_periods=12 ).fit().fittedvalues#.shift(-1)
print(df.head(), df.tail())
# Out:
#             file_size_gb         DES12     DES12_mul
# Date
# 2012-04-01  57843.503303  56077.569292  57922.180154
# 2012-05-01  53755.010719  56051.770372  55858.405763
# 2012-06-01  51089.201694  55433.751500  55898.739600
# 2012-07-01  57436.068959  56057.630245  57597.438492
# 2012-08-01  59746.605215  57074.852144  55893.418250              file_size_gb          DES12      DES12_mul
# Date
# 2022-08-01  201925.201299  201307.961060  200468.755358
# 2022-09-01  200120.592662  202996.256561  206756.728054
# 2022-10-01  208974.574449  206075.492118  220047.950590
# 2022-11-01  210865.107593  209091.068153  208907.318959
# 2022-12-01  208009.046105            NaN  202827.541532

# %%
df = df[:-1]
print(df.head(), df.tail())
# Out:
#             file_size_gb         DES12     DES12_mul
# Date
# 2012-04-01  57843.503303  56077.569292  57922.180154
# 2012-05-01  53755.010719  56051.770372  55858.405763
# 2012-06-01  51089.201694  55433.751500  55898.739600
# 2012-07-01  57436.068959  56057.630245  57597.438492
# 2012-08-01  59746.605215  57074.852144  55893.418250              file_size_gb          DES12      DES12_mul
# Date
# 2022-07-01  207857.828844  198862.908148  203130.948487
# 2022-08-01  201925.201299  201307.961060  200468.755358
# 2022-09-01  200120.592662  202996.256561  206756.728054
# 2022-10-01  208974.574449  206075.492118  220047.950590
# 2022-11-01  210865.107593  209091.068153  208907.318959

# %%
df.plot(figsize=(8,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.iloc[-36:].plot(figsize=(8,5)) #the recent 3 yrs, 2020~2022
# Out:
# <Axes: xlabel='Date'>

# %%
# mul > add (The mul model includes seasonality more than additive model)
df = df[['file_size_gb', 'DES12_mul']]
df.head()
# Out:
#             file_size_gb     DES12_mul
# Date
# 2012-04-01  57843.503303  57922.180154
# 2012-05-01  53755.010719  55858.405763
# 2012-06-01  51089.201694  55898.739600
# 2012-07-01  57436.068959  57597.438492
# 2012-08-01  59746.605215  55893.418250

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # 3-2) ETC Decomposition
# - additive model(linear increasing trend, regular seasonality)
# - multiplicative model(exponential increasing trend, non-linear changes. EX) stocks, NASDAQ)

# %%
df = df[['file_size_gb', 'DES12_mul']]
print(df.head(), df.tail())
# Out:
#             file_size_gb     DES12_mul
# Date
# 2012-04-01  57843.503303  57922.180154
# 2012-05-01  53755.010719  55858.405763
# 2012-06-01  51089.201694  55898.739600
# 2012-07-01  57436.068959  57597.438492
# 2012-08-01  59746.605215  55893.418250              file_size_gb      DES12_mul
# Date
# 2022-07-01  207857.828844  203130.948487
# 2022-08-01  201925.201299  200468.755358
# 2022-09-01  200120.592662  206756.728054
# 2022-10-01  208974.574449  220047.950590
# 2022-11-01  210865.107593  208907.318959

# %%
result = seasonal_decompose(df['file_size_gb'], model='add')
result.plot();

# %%
result = seasonal_decompose(df['DES12_mul'], model='add')
result.plot();

# %% [markdown]
# - Checking the upward trend and the clear seasonal factor pattern, and increasing residuals(random) since 2018

# %% [markdown]
# # 3-3) auto_arima() to find orders(p,d,q)

# %%
# w/original data
auto_arima(df[['file_size_gb']], seasonal=True, m=12).summary()# (2, 1, 0)x(0, 0, [1, 2], 12)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                  128
# Model:             SARIMAX(2, 1, 0)x(0, 0, [1, 2], 12)   Log Likelihood               -1304.189
# Date:                                 Thu, 16 Mar 2023   AIC                           2620.378
# Time:                                         17:46:42   BIC                           2637.443
# Sample:                                     04-01-2012   HQIC                          2627.311
#                                           - 11-01-2022
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2724.9898    978.666      2.784      0.005     806.840    4643.140
# ar.L1         -0.5964      0.056    -10.711      0.000      -0.706      -0.487
# ar.L2         -0.3285      0.059     -5.552      0.000      -0.444      -0.213
# ma.S.L12       0.2668      0.073      3.672      0.000       0.124       0.409
# ma.S.L24       0.1471      0.106      1.382      0.167      -0.062       0.356
# sigma2      4.961e+07      0.030   1.65e+09      0.000    4.96e+07    4.96e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.21   Jarque-Bera (JB):                 8.52
# Prob(Q):                              0.27   Prob(JB):                         0.01
# Heteroskedasticity (H):               3.44   Skew:                             0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.76e+24. Standard errors may be unstable.
# """

# %%
# w/ DES data
auto_arima(df[['DES12_mul']], seasonal=True, m=12).summary()# (0, 1, 0)x(0, 1, 0, 12)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  128
# Model:             SARIMAX(0, 1, 0)x(0, 1, 0, 12)   Log Likelihood               -1033.882
# Date:                            Thu, 16 Mar 2023   AIC                           2069.763
# Time:                                    17:46:44   BIC                           2072.508
# Sample:                                04-01-2012   HQIC                          2070.878
#                                      - 11-01-2022
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.732e+06    3.2e+05     11.673      0.000    3.11e+06    4.36e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.54   Jarque-Bera (JB):                34.00
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               8.24   Skew:                             0.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # 3-4) Split train/test & training the candidate models

# %%
#Set the recent one year(2022) for testing! 
train = df.iloc[:len(df)-12]
test = df.iloc[len(df)-12:]
print(len(train), len(test))
# Out:
# 116 12

# %%
print(train.head(), test.head())
# Out:
#             file_size_gb     DES12_mul
# Date
# 2012-04-01  57843.503303  57922.180154
# 2012-05-01  53755.010719  55858.405763
# 2012-06-01  51089.201694  55898.739600
# 2012-07-01  57436.068959  57597.438492
# 2012-08-01  59746.605215  55893.418250              file_size_gb      DES12_mul
# Date
# 2021-12-01  184692.054883  179284.587164
# 2022-01-01  179978.746271  186055.101579
# 2022-02-01  172266.099968  174876.506687
# 2022-03-01  198599.452134  188865.113467
# 2022-04-01  189866.486698  190808.270385

# %%
print(train.tail(), test.tail())
# Out:
#              file_size_gb      DES12_mul
# Date
# 2021-07-01  179806.431554  184279.605800
# 2021-08-01  172244.305162  178807.996681
# 2021-09-01  185893.428650  181132.857993
# 2021-10-01  190912.447724  194060.680326
# 2021-11-01  189518.573737  184745.869440              file_size_gb      DES12_mul
# Date
# 2022-07-01  207857.828844  203130.948487
# 2022-08-01  201925.201299  200468.755358
# 2022-09-01  200120.592662  206756.728054
# 2022-10-01  208974.574449  220047.950590
# 2022-11-01  210865.107593  208907.318959

# %%
#candidate 1) SARIMA(2,1,0)x(0,0,1,12) model for training
model1 = SARIMAX(train['file_size_gb'], order=(2,1,0), seasonal_order=(0,0,1,12))
results1 = model1.fit()
results1.summary()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03089D+01    |proj g|=  1.81069D-01
#
# At iterate    5    f=  1.01748D+01    |proj g|=  2.50307D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      7      9      1     0     0   3.974D-05   1.017D+01
#   F =   10.174818004684742
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                         file_size_gb   No. Observations:                  116
# Model:             SARIMAX(2, 1, 0)x(0, 0, [1], 12)   Log Likelihood               -1180.279
# Date:                              Thu, 16 Mar 2023   AIC                           2368.558
# Time:                                      17:47:00   BIC                           2379.538
# Sample:                                  04-01-2012   HQIC                          2373.014
#                                        - 11-01-2021
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4679      0.054     -8.593      0.000      -0.575      -0.361
# ar.L2         -0.3189      0.053     -6.068      0.000      -0.422      -0.216
# ma.S.L12       0.3421      0.082      4.177      0.000       0.182       0.503
# sigma2      5.035e+07   2.68e-10   1.88e+17      0.000    5.04e+07    5.04e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.93   Jarque-Bera (JB):                 1.46
# Prob(Q):                              0.17   Prob(JB):                         0.48
# Heteroskedasticity (H):               3.39   Skew:                             0.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.15e+33. Standard errors may be unstable.
# """

# %%
#candidate 2) SARIMA(2,1,0)x(0,0,2,12) model for training
model2 = SARIMAX(train['file_size_gb'], order=(2,1,0), seasonal_order=(0,0,2,12))
results2 = model2.fit()
results2.summary()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04183D+01    |proj g|=  3.10780D-01
#
# At iterate    5    f=  1.01543D+01    |proj g|=  1.49628D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      9     10      1     0     0   1.553D-05   1.015D+01
#   F =   10.154204309160015
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                            file_size_gb   No. Observations:                  116
# Model:             SARIMAX(2, 1, 0)x(0, 0, [1, 2], 12)   Log Likelihood               -1177.888
# Date:                                 Thu, 16 Mar 2023   AIC                           2365.775
# Time:                                         17:47:01   BIC                           2379.500
# Sample:                                     04-01-2012   HQIC                          2371.346
#                                           - 11-01-2021
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4658      0.058     -8.058      0.000      -0.579      -0.352
# ar.L2         -0.3161      0.055     -5.726      0.000      -0.424      -0.208
# ma.S.L12       0.3534      0.070      5.069      0.000       0.217       0.490
# ma.S.L24       0.2161      0.124      1.738      0.082      -0.028       0.460
# sigma2      5.035e+07   4.42e-10   1.14e+17      0.000    5.04e+07    5.04e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.77   Jarque-Bera (JB):                 2.31
# Prob(Q):                              0.18   Prob(JB):                         0.32
# Heteroskedasticity (H):               2.69   Skew:                            -0.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.15e+32. Standard errors may be unstable.
# """

# %%
# model3 : Double Exponential Smoothing with multiplicative 
model3 = SARIMAX(train['DES12_mul'], order=(0,1,0), seasonal_order=(0,1,0,12))
results3 = model3.fit()
results3.summary()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.84649D+00    |proj g|=  7.16712D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      5      1     0     0   6.585D-06   7.843D+00
#   F =   7.8432591553368711
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          DES12_mul   No. Observations:                  116
# Model:             SARIMAX(0, 1, 0)x(0, 1, 0, 12)   Log Likelihood                -909.818
# Date:                            Thu, 16 Mar 2023   AIC                           1821.636
# Time:                                    17:47:01   BIC                           1824.271
# Sample:                                04-01-2012   HQIC                          1822.703
#                                      - 11-01-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       2.72e+06   3.76e+05      7.239      0.000    1.98e+06    3.46e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.97   Jarque-Bera (JB):                 0.03
# Prob(Q):                              0.16   Prob(JB):                         0.98
# Heteroskedasticity (H):               6.06   Skew:                            -0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # 3-5) Predict w/ candidate models

# %%
start = len(train)
end = len(train) + len(test) - 1
predictions1 = results1.predict(start, end, type='levels').rename('SARIMA Predictions w/ model1')
predictions2 = results2.predict(start, end, type='levels').rename('SARIMA Predictions w/ model2')
predictions3 = results3.predict(start, end, type='levels').rename('SARIMA Predictions w/ model3')

# %%
test['file_size_gb'].plot(figsize=(8,5), legend=True)
predictions1.plot(legend=True)
predictions2.plot(legend=True)
predictions3.plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # 3-6) Evaluate models using MAPE, WMAPE

# %%
print('[MODEL1]',
      'RMSE : ',rmse(test['file_size_gb'], predictions1), 
      'MSLE : ',mean_squared_log_error(test['file_size_gb'], predictions1), 
      'MAPE : ',np.mean(np.abs((test['file_size_gb'] - predictions1)/test['file_size_gb']))*100)

print('[MODEL2]',
      'RMSE : ',rmse(test['file_size_gb'], predictions2), 
      'MSLE : ',mean_squared_log_error(test['file_size_gb'], predictions2), 
      'MAPE : ',np.mean(np.abs((test['file_size_gb'] - predictions2)/test['file_size_gb']))*100)

print('[MODEL3]',
      'RMSE : ',rmse(test['DES12_mul'], predictions3), 
      'MSLE : ',mean_squared_log_error(test['DES12_mul'], predictions3), 
      'MAPE : ',np.mean(np.abs((test['DES12_mul'] - predictions3)/test['DES12_mul']))*100)


print('[MAPE]')
print(mean_absolute_percentage_error(test['file_size_gb'], predictions1)*100)
print(mean_absolute_percentage_error(test['file_size_gb'], predictions2)*100)
print(mean_absolute_percentage_error(test['DES12_mul'], predictions3)*100)

print('[WMAPE]')
print(sum(abs(test['file_size_gb'] - predictions1)) / sum(abs(test['file_size_gb']))*100)
print(sum(abs(test['file_size_gb'] - predictions2)) / sum(abs(test['file_size_gb']))*100)
print(sum(abs(test['DES12_mul'] - predictions3)) / sum(abs(test['DES12_mul']))*100)
# Out:
# [MODEL1] RMSE :  11930.860918111246 MSLE :  0.0037410681702538078 MAPE :  5.43067393539885
# [MODEL2] RMSE :  10950.832124243476 MSLE :  0.0031642664781191157 MAPE :  4.867418319142156
# [MODEL3] RMSE :  10405.853326935317 MSLE :  0.0027322184032219352 MAPE :  4.289029192580632
# [MAPE]
# 5.43067393539885
# 4.867418319142156
# 4.289029192580632
# [WMAPE]
# 5.48310725162198
# 4.901851720538137
# 4.447606579099069

# %% [markdown]
# # 3-7) Predict 'file_size_gb' in Jan 2023

# %%
model = SARIMAX(train['file_size_gb'], order=(2,1,0), seasonal_order=(0,0,2,12))
results = model.fit()
fcast = results.predict(start=len(df), end=len(df)+12, typ='levels').rename('SARIMA Forecast')
fcast
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04183D+01    |proj g|=  3.10780D-01
#
# At iterate    5    f=  1.01543D+01    |proj g|=  1.49628D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      9     10      1     0     0   1.553D-05   1.015D+01
#   F =   10.154204309160015
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# 2022-12-01    196471.869657
# 2023-01-01    194165.925269
# 2023-02-01    194912.536065
# 2023-03-01    198551.027525
# 2023-04-01    201249.869534
# 2023-05-01    194747.871965
# 2023-06-01    195902.764561
# 2023-07-01    196749.878892
# 2023-08-01    195778.775934
# 2023-09-01    198415.340398
# 2023-10-01    198952.705964
# 2023-11-01    199833.720849
# 2023-12-01    199253.509520
# Freq: MS, Name: SARIMA Forecast, dtype: float64

# %%
df['file_size_gb'].plot(figsize=(8,6), legend=True)
fcast.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
model = SARIMAX(train['DES12_mul'], order=(0,1,0), seasonal_order=(0,1,0,12))
results = model.fit()
fcast = results.predict(start=len(df), end=len(df)+12, typ='levels').rename('SARIMA Forecast')
fcast
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.84649D+00    |proj g|=  7.16712D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      5      1     0     0   6.585D-06   7.843D+00
#   F =   7.8432591553368711
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# 2022-12-01    184861.138743
# 2023-01-01    190593.017625
# 2023-02-01    179133.903219
# 2023-03-01    192149.355889
# 2023-04-01    194185.633756
# 2023-05-01    193054.927657
# 2023-06-01    191770.908848
# 2023-07-01    200959.785109
# 2023-08-01    195488.175990
# 2023-09-01    197813.037302
# 2023-10-01    210740.859635
# 2023-11-01    201426.048749
# 2023-12-01    193201.228398
# Freq: MS, Name: SARIMA Forecast, dtype: float64

# %%
df['DES12_mul'].plot(figsize=(8,6), legend=True)
fcast.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
model = SARIMAX(train['DES12_mul'], order=(0,1,0), seasonal_order=(0,1,0,12))
results = model.fit()
fcast = results.predict(start=len(df), end=len(df)+24, typ='levels').rename('SARIMA Forecast')
df['DES12_mul'].plot(figsize=(8,6), legend=True)
fcast.plot()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.84649D+00    |proj g|=  7.16712D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      5      1     0     0   6.585D-06   7.843D+00
#   F =   7.8432591553368711
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# <Axes: xlabel='Date'>
